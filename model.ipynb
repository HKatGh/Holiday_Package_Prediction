# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df['Designation'].value_counts()
# Out:
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['TypeofContact']=df['TypeofContact'].fillna('Self Enquiry')

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['DurationOfPitch']=df['DurationOfPitch'].fillna(df['DurationOfPitch'].mean())

# %%
df['NumberOfFollowups']=df['NumberOfFollowups'].fillna(4.0)

# %%
df['PreferredPropertyStar']=df['PreferredPropertyStar'].fillna(3.0)

# %%
df['NumberOfChildrenVisiting']=df['NumberOfChildrenVisiting'].fillna(1.0)

# %%
df['MonthlyIncome']=df['MonthlyIncome'].fillna(df['MonthlyIncome'].mean())

# %%
df['NumberOfTrips'].mode()
# Out:
# 0    2.0
# Name: NumberOfTrips, dtype: float64

# %%
df['NumberOfTrips']=df['NumberOfTrips'].fillna(2.0)

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
df.shape
# Out:
# (4888, 20)

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %%
df.head()
# Out:
#    CustomerID  ProdTaken        Age    TypeofContact  CityTier  \
# 0      200000          1  41.000000     Self Enquiry         3
# 1      200001          0  49.000000  Company Invited         1
# 2      200002          1  37.000000     Self Enquiry         1
# 3      200003          0  33.000000  Company Invited         1
# 4      200004          0  37.622265     Self Enquiry         1
#
#    DurationOfPitch      Occupation  Gender  NumberOfPersonVisiting  \
# 0              6.0        Salaried  Female                       3
# 1             14.0        Salaried    Male                       3
# 2              8.0     Free Lancer    Male                       3
# 3              9.0        Salaried  Female                       2
# 4              8.0  Small Business    Male                       2
#
#    NumberOfFollowups ProductPitched  PreferredPropertyStar MaritalStatus  \
# 0                3.0         Deluxe                    3.0        Single
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4888 non-null   float64
#  3   TypeofContact             4888 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4888 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4888 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4888 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3469
# Company Invited    1419
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder(sparse_output=False)

# %%
df[['TypeofContact']]
# Out:
#         TypeofContact
# 0        Self Enquiry
# 1     Company Invited
# 2        Self Enquiry
# 3     Company Invited
# 4        Self Enquiry
# ...               ...
# 4883     Self Enquiry
# 4884  Company Invited
# 4885     Self Enquiry
# 4886     Self Enquiry
# 4887     Self Enquiry
#
# [4888 rows x 1 columns]

# %%
encoded=one.fit_transform(df[['TypeofContact']])

# %%
df_encoded=pd.DataFrame(encoded,columns=one.get_feature_names_out())

# %%
df=pd.concat([df,df_encoded],axis=1)

# %%
df=df.drop(['TypeofContact'],axis=1)

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Occupation']=le.fit_transform(df['Occupation'])

# %%
df
# Out:
#       CustomerID  ProdTaken        Age  CityTier  DurationOfPitch  Occupation  \
# 0         200000          1  41.000000         3              6.0           2
# 1         200001          0  49.000000         1             14.0           2
# 2         200002          1  37.000000         1              8.0           0
# 3         200003          0  33.000000         1              9.0           2
# 4         200004          0  37.622265         1              8.0           3
# ...          ...        ...        ...       ...              ...         ...
# 4883      204883          1  49.000000         3              9.0           3
# 4884      204884          1  28.000000         1             31.0           2
# 4885      204885          1  52.000000         3             17.0           2
# 4886      204886          1  19.000000         3             16.0           3
# 4887      204887          1  36.000000         1             14.0           2
#
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
for index,gen in enumerate(df['Gender']):
    if df['Gender'][index]=='Fe Male':
        df['Gender'][index]='Female'
# Out:
# C:\Users\dkuma\AppData\Local\Temp\ipykernel_21340\2131454536.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Gender'][index]='Female'
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
df
# Out:
#       CustomerID  ProdTaken        Age  CityTier  DurationOfPitch  Occupation  \
# 0         200000          1  41.000000         3              6.0           2
# 1         200001          0  49.000000         1             14.0           2
# 2         200002          1  37.000000         1              8.0           0
# 3         200003          0  33.000000         1              9.0           2
# 4         200004          0  37.622265         1              8.0           3
# ...          ...        ...        ...       ...              ...         ...
# 4883      204883          1  49.000000         3              9.0           3
# 4884      204884          1  28.000000         1             31.0           2
# 4885      204885          1  52.000000         3             17.0           2
# 4886      204886          1  19.000000         3             16.0           3
# 4887      204887          1  36.000000         1             14.0           2
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df
# Out:
#       CustomerID  ProdTaken        Age  CityTier  DurationOfPitch  Occupation  \
# 0         200000          1  41.000000         3              6.0           2
# 1         200001          0  49.000000         1             14.0           2
# 2         200002          1  37.000000         1              8.0           0
# 3         200003          0  33.000000         1              9.0           2
# 4         200004          0  37.622265         1              8.0           3
# ...          ...        ...        ...       ...              ...         ...
# 4883      204883          1  49.000000         3              9.0           3
# 4884      204884          1  28.000000         1             31.0           2
# 4885      204885          1  52.000000         3             17.0           2
# 4886      204886          1  19.000000         3             16.0           3
# 4887      204887          1  36.000000         1             14.0           2
#
# ...

# %%
df['ProductPitched'].value_counts()
# Out:
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: count, dtype: int64

# %%
df['ProductPitched']=le.fit_transform(df['ProductPitched'])

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'TypeofContact_Company Invited', 'TypeofContact_Self Enquiry'],
#       dtype='object')

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
df['Designation'].value_counts()
# Out:
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64

# %%
df['Designation']=le.fit_transform(df['Designation'])

# %%
df
# Out:
#       CustomerID  ProdTaken        Age  CityTier  DurationOfPitch  Occupation  \
# 0         200000          1  41.000000         3              6.0           2
# 1         200001          0  49.000000         1             14.0           2
# 2         200002          1  37.000000         1              8.0           0
# 3         200003          0  33.000000         1              9.0           2
# 4         200004          0  37.622265         1              8.0           3
# ...          ...        ...        ...       ...              ...         ...
# 4883      204883          1  49.000000         3              9.0           3
# 4884      204884          1  28.000000         1             31.0           2
# 4885      204885          1  52.000000         3             17.0           2
# 4886      204886          1  19.000000         3             16.0           3
# 4887      204887          1  36.000000         1             14.0           2
#
# ...

# %%
df_ID=df['CustomerID']

# %%
df.drop(['CustomerID'],inplace=True,axis=1)

# %%
df
# Out:
#       ProdTaken        Age  CityTier  DurationOfPitch  Occupation  Gender  \
# 0             1  41.000000         3              6.0           2       0
# 1             0  49.000000         1             14.0           2       1
# 2             1  37.000000         1              8.0           0       1
# 3             0  33.000000         1              9.0           2       0
# 4             0  37.622265         1              8.0           3       1
# ...         ...        ...       ...              ...         ...     ...
# 4883          1  49.000000         3              9.0           3       1
# 4884          1  28.000000         1             31.0           2       1
# 4885          1  52.000000         3             17.0           2       0
# 4886          1  19.000000         3             16.0           3       1
# 4887          1  36.000000         1             14.0           2       1
#
#       NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# ...

# %%
matrix=df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(matrix)
# Out:
# <Axes: >

# %%
matrix
# Out:
#                                ProdTaken       Age  CityTier  DurationOfPitch  \
# ProdTaken                       1.000000 -0.143717  0.086852         0.076297
# Age                            -0.143717  1.000000 -0.015344        -0.011280
# CityTier                        0.086852 -0.015344  1.000000         0.022020
# DurationOfPitch                 0.076297 -0.011280  0.022020         1.000000
# Occupation                     -0.041042  0.026752  0.131834         0.052028
# Gender                          0.031112 -0.038409 -0.021754         0.008993
# NumberOfPersonVisiting          0.009627  0.011298 -0.001671         0.063310
# NumberOfFollowups               0.111560 -0.002765  0.024333         0.008689
# ProductPitched                 -0.161262  0.444603  0.141485         0.023994
# PreferredPropertyStar           0.098704 -0.015605 -0.008479        -0.005921
# MaritalStatus                   0.147186 -0.093519  0.035707        -0.008948
# ...

# %%
df.drop(['NumberOfFollowups','NumberOfPersonVisiting'],axis=1,inplace=True)

# %% [markdown]
# less related with product taken =NumberOfChildrenVisiting,number of perso
# passport is highly related with prod Taker

# %% [markdown]
# df

# %%
df
# Out:
#       ProdTaken        Age  CityTier  DurationOfPitch  Occupation  Gender  \
# 0             1  41.000000         3              6.0           2       0
# 1             0  49.000000         1             14.0           2       1
# 2             1  37.000000         1              8.0           0       1
# 3             0  33.000000         1              9.0           2       0
# 4             0  37.622265         1              8.0           3       1
# ...         ...        ...       ...              ...         ...     ...
# 4883          1  49.000000         3              9.0           3       1
# 4884          1  28.000000         1             31.0           2       1
# 4885          1  52.000000         3             17.0           2       0
# 4886          1  19.000000         3             16.0           3       1
# 4887          1  36.000000         1             14.0           2       1
#
#       ProductPitched  PreferredPropertyStar  MaritalStatus  NumberOfTrips  \
# ...

# %%
x=df.drop(['ProdTaken'],axis=1)

# %%
y=df['ProdTaken']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB  # or BernoulliNB, MultinomialNB as needed
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve

# %%
models={"Logistic":LogisticRegression(),
         "SVM":SVC(),
         "KNN":KNeighborsClassifier(),
         "Decision Tree":DecisionTreeClassifier(),
         "RandomForest":RandomForestClassifier(),
         "naive bayes":GaussianNB(),
         "Adaboost":AdaBoostClassifier(),
         "Gradient Boosting":GradientBoostingClassifier()}

# %%
for index,model in enumerate(models.values()):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print("............................")
    print(f"{list(models.keys())[index]}")
    print(f"accuracy_score :{accuracy_score(y_test,y_pred)}")
    print(f"confusion matrix :{confusion_matrix(y_test,y_pred)}")
    print(f"precision score :{precision_score(y_test,y_pred)}")
    print(f"recall score :{recall_score(y_test,y_pred)}")
    print(f"f1_score :{f1_score(y_test,y_pred)}")
    print("..........................")
# Out:
# c:\Users\dkuma\Desktop\Quant\MACHINE LEARNING\code\venv\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ............................
# Logistic
# accuracy_score :0.8327137546468402
# confusion matrix :[[1292   29]
#  [ 241   52]]
# precision score :0.6419753086419753
# recall score :0.17747440273037543
# f1_score :0.27807486631016043
# ..........................
# ............................
# SVM
# accuracy_score :0.8184634448574969
# confusion matrix :[[1321    0]
#  [ 293    0]]
# precision score :0.0
# recall score :0.0
# ...

# %%
# Out:
# 144     0
# 79      0
# 2098    0
# 4738    0
# 2858    1
#        ..
# 1227    0
# 3463    0
# 2274    0
# 4404    0
# 324     0
# Name: ProdTaken, Length: 1614, dtype: int64

# %%
models={"RandomForest":RandomForestClassifier(),
         
         "Adaboost":AdaBoostClassifier(),
         "Gradient Boosting":GradientBoostingClassifier()}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params={"loss":['log_loss', 'exponential'],
        "learning_rate":[0.1,0.01,0.001,10],
        "n_estimators":[100,50,200],
        'criterion':['friedman_mse', 'squared_error']
        }

# %%
rs=RandomizedSearchCV(GradientBoostingClassifier(),param_distributions=params,scoring='accuracy',cv=5)

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#                    param_distributions={'criterion': ['friedman_mse',
#                                                       'squared_error'],
#                                         'learning_rate': [0.1, 0.01, 0.001, 10],
#                                         'loss': ['log_loss', 'exponential'],
#                                         'n_estimators': [100, 50, 200]},
#                    scoring='accuracy')

# %%
rs.best_params_
# Out:
# {'n_estimators': 200,
#  'loss': 'exponential',
#  'learning_rate': 0.1,
#  'criterion': 'friedman_mse'}

# %%
y_pred=rs.predict(X_test)

# %%
rs.best_score_
# Out:
# np.float64(0.861019679249247)

# %%
print(f"accuracy_score :{accuracy_score(y_test,y_pred)}")
print(f"confusion matrix :{confusion_matrix(y_test,y_pred)}")
print(f"precision score :{precision_score(y_test,y_pred)}")
print(f"recall score :{recall_score(y_test,y_pred)}")
print(f"f1_score :{f1_score(y_test,y_pred)}")
# Out:
# accuracy_score :0.872366790582404
# confusion matrix :[[1280   41]
#  [ 165  128]]
# precision score :0.757396449704142
# recall score :0.43686006825938567
# f1_score :0.5541125541125541
